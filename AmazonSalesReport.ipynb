# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv(r"C:\Users\sanja\Documents\Tableau\E-Commerce Sales Dataset\Amazon Sale Report.csv")
dataset.head()
# Out:
# C:\Users\sanja\AppData\Local\Temp\ipykernel_15564\2402793128.py:1: DtypeWarning: Columns (23) have mixed types. Specify dtype option on import or set low_memory=False.
#   dataset = pd.read_csv(r"C:\Users\sanja\Documents\Tableau\E-Commerce Sales Dataset\Amazon Sale Report.csv")
#    index             Order ID      Date                        Status  \
# 0      0  405-8078784-5731545  04-30-22                     Cancelled
# 1      1  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2      2  404-0687676-7273146  04-30-22                       Shipped
# 3      3  403-9615377-8133951  04-30-22                     Cancelled
# 4      4  407-1069790-7240320  04-30-22                       Shipped
#
#   Fulfilment Sales Channel  ship-service-level    Style              SKU  \
# 0   Merchant      Amazon.in           Standard   SET389   SET389-KR-NP-S
# 1   Merchant      Amazon.in           Standard  JNE3781  JNE3781-KR-XXXL
# ...

# %%
dataset.columns
# Out:
# Index(['index', 'Order ID', 'Date', 'Status', 'Fulfilment', 'Sales Channel ',
#        'ship-service-level', 'Style', 'SKU', 'Category', 'Size', 'ASIN',
#        'Courier Status', 'Qty', 'currency', 'Amount', 'ship-city',
#        'ship-state', 'ship-postal-code', 'ship-country', 'promotion-ids',
#        'B2B', 'fulfilled-by', 'Unnamed: 22'],
#       dtype='object')

# %%
dataset = dataset.drop(['index','Unnamed: 22'], axis=1)

# %%
dataset.isna().sum()
# Out:
# Order ID                  0
# Date                      0
# Status                    0
# Fulfilment                0
# Sales Channel             0
# ship-service-level        0
# Style                     0
# SKU                       0
# Category                  0
# Size                      0
# ASIN                      0
# Courier Status         6872
# Qty                       0
# currency               7795
# Amount                 7795
# ship-city                33
# ship-state               33
# ship-postal-code         33
# ship-country             33
# promotion-ids         49153
# B2B                       0
# fulfilled-by          89698
# dtype: int64

# %%
dataset['Courier Status'].unique()
# Out:
# array([nan, 'Shipped', 'Cancelled', 'Unshipped'], dtype=object)

# %%
dataset[dataset['Courier Status'].isna()]
# Out:
#                    Order ID      Date     Status Fulfilment Sales Channel   \
# 0       405-8078784-5731545  04-30-22  Cancelled   Merchant      Amazon.in
# 3       403-9615377-8133951  04-30-22  Cancelled   Merchant      Amazon.in
# 23      404-6019946-2909948  04-30-22  Cancelled   Merchant      Amazon.in
# 29      404-5933402-8801952  04-30-22  Cancelled   Merchant      Amazon.in
# 83      404-6522553-9345930  04-30-22  Cancelled   Merchant      Amazon.in
# ...                     ...       ...        ...        ...            ...
# 128762  402-4651401-6366769  06-01-22  Cancelled   Merchant      Amazon.in
# 128808  408-4182027-2307535  06-01-22  Cancelled   Merchant      Amazon.in
# 128855  402-1958677-2521967  06-01-22  Cancelled   Merchant      Amazon.in
# 128875  403-9524128-9243508  06-01-22  Cancelled   Merchant      Amazon.in
# 128890  407-0116398-1810752  05-31-22  Cancelled   Merchant      Amazon.in
#
# ...

# %%
dataset['Courier Status'] = dataset['Courier Status'].fillna('Cancelled')
dataset['Courier Status'].unique()
# Out:
# array(['Cancelled', 'Shipped', 'Unshipped'], dtype=object)

# %%
dataset['Courier Status'].isna().sum()
# Out:
# 0

# %%
dataset[dataset['currency'].isna()]
# Out:
#                    Order ID      Date     Status Fulfilment Sales Channel   \
# 8       407-5443024-5233168  04-30-22  Cancelled     Amazon      Amazon.in
# 29      404-5933402-8801952  04-30-22  Cancelled   Merchant      Amazon.in
# 65      171-4137548-0481151  04-30-22  Cancelled     Amazon      Amazon.in
# 84      403-9950518-0349133  04-30-22  Cancelled     Amazon      Amazon.in
# 95      405-9112089-3379536  04-30-22  Cancelled     Amazon      Amazon.in
# ...                     ...       ...        ...        ...            ...
# 128903  406-3923120-4345139  05-31-22  Cancelled     Amazon      Amazon.in
# 128907  403-6757403-6097100  05-31-22  Cancelled     Amazon      Amazon.in
# 128908  403-6757403-6097100  05-31-22  Cancelled     Amazon      Amazon.in
# 128958  408-9513596-4393945  05-31-22  Cancelled     Amazon      Amazon.in
# 128967  404-5182288-1653947  05-31-22  Cancelled     Amazon      Amazon.in
#
# ...

# %%
dataset.shape
# Out:
# (128975, 22)

# %%
dataset['Amount'].dropna()
# Out:
# 0          647.62
# 1          406.00
# 2          329.00
# 3          753.33
# 4          574.00
#            ...
# 128970     517.00
# 128971     999.00
# 128972     690.00
# 128973    1199.00
# 128974     696.00
# Name: Amount, Length: 121180, dtype: float64

# %%
dataset[['currency', 'Amount']] = dataset[['currency', 'Amount']].fillna({'currency': 'INR', 'Amount':0})
dataset.isna().sum()
# Out:
# Order ID                  0
# Date                      0
# Status                    0
# Fulfilment                0
# Sales Channel             0
# ship-service-level        0
# Style                     0
# SKU                       0
# Category                  0
# Size                      0
# ASIN                      0
# Courier Status            0
# Qty                       0
# currency                  0
# Amount                    0
# ship-city                33
# ship-state               33
# ship-postal-code         33
# ship-country             33
# promotion-ids         49153
# B2B                       0
# fulfilled-by          89698
# dtype: int64

# %%
dataset['promotion-ids'] = dataset['promotion-ids'].fillna("None")
dataset.isna().sum()
# Out:
# Order ID                  0
# Date                      0
# Status                    0
# Fulfilment                0
# Sales Channel             0
# ship-service-level        0
# Style                     0
# SKU                       0
# Category                  0
# Size                      0
# ASIN                      0
# Courier Status            0
# Qty                       0
# currency                  0
# Amount                    0
# ship-city                33
# ship-state               33
# ship-postal-code         33
# ship-country             33
# promotion-ids             0
# B2B                       0
# fulfilled-by          89698
# dtype: int64

# %%
dataset['fulfilled-by'] = dataset['fulfilled-by'].fillna("None")
dataset.isna().sum()
# Out:
# Order ID               0
# Date                   0
# Status                 0
# Fulfilment             0
# Sales Channel          0
# ship-service-level     0
# Style                  0
# SKU                    0
# Category               0
# Size                   0
# ASIN                   0
# Courier Status         0
# Qty                    0
# currency               0
# Amount                 0
# ship-city             33
# ship-state            33
# ship-postal-code      33
# ship-country          33
# promotion-ids          0
# B2B                    0
# fulfilled-by           0
# dtype: int64

# %%
dataset = dataset.dropna()
dataset
# Out:
#                    Order ID      Date                        Status  \
# 0       405-8078784-5731545  04-30-22                     Cancelled
# 1       171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2       404-0687676-7273146  04-30-22                       Shipped
# 3       403-9615377-8133951  04-30-22                     Cancelled
# 4       407-1069790-7240320  04-30-22                       Shipped
# ...                     ...       ...                           ...
# 128970  406-6001380-7673107  05-31-22                       Shipped
# 128971  402-9551604-7544318  05-31-22                       Shipped
# 128972  407-9547469-3152358  05-31-22                       Shipped
# 128973  402-6184140-0545956  05-31-22                       Shipped
# 128974  408-7436540-8728312  05-31-22                       Shipped
#
#        Fulfilment Sales Channel  ship-service-level    Style              SKU  \
# ...

# %%
dataset['ship-state'].unique()
# Out:
# array(['MAHARASHTRA', 'KARNATAKA', 'PUDUCHERRY', 'TAMIL NADU',
#        'UTTAR PRADESH', 'CHANDIGARH', 'TELANGANA', 'ANDHRA PRADESH',
#        'RAJASTHAN', 'DELHI', 'HARYANA', 'ASSAM', 'JHARKHAND',
#        'CHHATTISGARH', 'ODISHA', 'KERALA', 'MADHYA PRADESH',
#        'WEST BENGAL', 'NAGALAND', 'Gujarat', 'UTTARAKHAND', 'BIHAR',
#        'JAMMU & KASHMIR', 'PUNJAB', 'HIMACHAL PRADESH',
#        'ARUNACHAL PRADESH', 'MANIPUR', 'Goa', 'MEGHALAYA', 'GOA',
#        'TRIPURA', 'LADAKH', 'DADRA AND NAGAR', 'SIKKIM', 'Delhi',
#        'ANDAMAN & NICOBAR ', 'Punjab', 'Rajshthan', 'Manipur',
#        'rajasthan', 'Odisha', 'NL', 'Bihar', 'MIZORAM', 'punjab',
#        'New Delhi', 'Rajasthan', 'Punjab/Mohali/Zirakpur', 'Puducherry',
#        'delhi', 'RJ', 'Chandigarh', 'orissa', 'LAKSHADWEEP', 'goa', 'PB',
#        'APO', 'Arunachal Pradesh', 'AR', 'Pondicherry', 'Sikkim',
#        'Arunachal pradesh', 'Nagaland', 'bihar', 'Mizoram', 'rajsthan',
# ...

# %%
dataset['ship-state'] = dataset['ship-state'].str.upper()
dataset['ship-state'].unique()
# Out:
# array(['MAHARASHTRA', 'KARNATAKA', 'PUDUCHERRY', 'TAMIL NADU',
#        'UTTAR PRADESH', 'CHANDIGARH', 'TELANGANA', 'ANDHRA PRADESH',
#        'RAJASTHAN', 'DELHI', 'HARYANA', 'ASSAM', 'JHARKHAND',
#        'CHHATTISGARH', 'ODISHA', 'KERALA', 'MADHYA PRADESH',
#        'WEST BENGAL', 'NAGALAND', 'GUJARAT', 'UTTARAKHAND', 'BIHAR',
#        'JAMMU & KASHMIR', 'PUNJAB', 'HIMACHAL PRADESH',
#        'ARUNACHAL PRADESH', 'MANIPUR', 'GOA', 'MEGHALAYA', 'TRIPURA',
#        'LADAKH', 'DADRA AND NAGAR', 'SIKKIM', 'ANDAMAN & NICOBAR ',
#        'RAJSHTHAN', 'NL', 'MIZORAM', 'NEW DELHI',
#        'PUNJAB/MOHALI/ZIRAKPUR', 'RJ', 'ORISSA', 'LAKSHADWEEP', 'PB',
#        'APO', 'AR', 'PONDICHERRY', 'RAJSTHAN'], dtype=object)

# %%
dataset['ship-state']=dataset['ship-state'].str.replace('RJ', 'RAJASTHAN')
dataset['ship-state'].unique()
# Out:
# array(['MAHARASHTRA', 'KARNATAKA', 'PUDUCHERRY', 'TAMIL NADU',
#        'UTTAR PRADESH', 'CHANDIGARH', 'TELANGANA', 'ANDHRA PRADESH',
#        'RAJASTHAN', 'DELHI', 'HARYANA', 'ASSAM', 'JHARKHAND',
#        'CHHATTISGARH', 'ODISHA', 'KERALA', 'MADHYA PRADESH',
#        'WEST BENGAL', 'NAGALAND', 'GUJARAT', 'UTTARAKHAND', 'BIHAR',
#        'JAMMU & KASHMIR', 'PUNJAB', 'HIMACHAL PRADESH',
#        'ARUNACHAL PRADESH', 'MANIPUR', 'GOA', 'MEGHALAYA', 'TRIPURA',
#        'LADAKH', 'DADRA AND NAGAR', 'SIKKIM', 'ANDAMAN & NICOBAR ',
#        'RAJSHTHAN', 'NL', 'MIZORAM', 'NEW DELHI',
#        'PUNJAB/MOHALI/ZIRAKPUR', 'ORISSA', 'LAKSHADWEEP', 'PB', 'APO',
#        'AR', 'PONDICHERRY', 'RAJSTHAN'], dtype=object)

# %%
dataset['ship-state']=dataset['ship-state'].str.replace('PUNJAB/MOHALI/ZIRAKPUR', 'PUNJAB')
dataset['ship-state'].unique()
# Out:
# array(['MAHARASHTRA', 'KARNATAKA', 'PUDUCHERRY', 'TAMIL NADU',
#        'UTTAR PRADESH', 'CHANDIGARH', 'TELANGANA', 'ANDHRA PRADESH',
#        'RAJASTHAN', 'DELHI', 'HARYANA', 'ASSAM', 'JHARKHAND',
#        'CHHATTISGARH', 'ODISHA', 'KERALA', 'MADHYA PRADESH',
#        'WEST BENGAL', 'NAGALAND', 'GUJARAT', 'UTTARAKHAND', 'BIHAR',
#        'JAMMU & KASHMIR', 'PUNJAB', 'HIMACHAL PRADESH',
#        'ARUNACHAL PRADESH', 'MANIPUR', 'GOA', 'MEGHALAYA', 'TRIPURA',
#        'LADAKH', 'DADRA AND NAGAR', 'SIKKIM', 'ANDAMAN & NICOBAR ',
#        'RAJSHTHAN', 'NL', 'MIZORAM', 'NEW DELHI', 'ORISSA', 'LAKSHADWEEP',
#        'PB', 'APO', 'AR', 'PONDICHERRY', 'RAJSTHAN'], dtype=object)

# %%
dataset['ship-state']=dataset['ship-state'].str.replace('NEW DELHI', 'DELHI')
dataset['ship-state'].unique()
# Out:
# array(['MAHARASHTRA', 'KARNATAKA', 'PUDUCHERRY', 'TAMIL NADU',
#        'UTTAR PRADESH', 'CHANDIGARH', 'TELANGANA', 'ANDHRA PRADESH',
#        'RAJASTHAN', 'DELHI', 'HARYANA', 'ASSAM', 'JHARKHAND',
#        'CHHATTISGARH', 'ODISHA', 'KERALA', 'MADHYA PRADESH',
#        'WEST BENGAL', 'NAGALAND', 'GUJARAT', 'UTTARAKHAND', 'BIHAR',
#        'JAMMU & KASHMIR', 'PUNJAB', 'HIMACHAL PRADESH',
#        'ARUNACHAL PRADESH', 'MANIPUR', 'GOA', 'MEGHALAYA', 'TRIPURA',
#        'LADAKH', 'DADRA AND NAGAR', 'SIKKIM', 'ANDAMAN & NICOBAR ',
#        'RAJSHTHAN', 'NL', 'MIZORAM', 'ORISSA', 'LAKSHADWEEP', 'PB', 'APO',
#        'AR', 'PONDICHERRY', 'RAJSTHAN'], dtype=object)

# %%
dataset['ship-state']=dataset['ship-state'].str.replace('DELHI', 'NEW DELHI')
dataset['ship-state'].unique()
# Out:
# array(['MAHARASHTRA', 'KARNATAKA', 'PUDUCHERRY', 'TAMIL NADU',
#        'UTTAR PRADESH', 'CHANDIGARH', 'TELANGANA', 'ANDHRA PRADESH',
#        'RAJASTHAN', 'NEW DELHI', 'HARYANA', 'ASSAM', 'JHARKHAND',
#        'CHHATTISGARH', 'ODISHA', 'KERALA', 'MADHYA PRADESH',
#        'WEST BENGAL', 'NAGALAND', 'GUJARAT', 'UTTARAKHAND', 'BIHAR',
#        'JAMMU & KASHMIR', 'PUNJAB', 'HIMACHAL PRADESH',
#        'ARUNACHAL PRADESH', 'MANIPUR', 'GOA', 'MEGHALAYA', 'TRIPURA',
#        'LADAKH', 'DADRA AND NAGAR', 'SIKKIM', 'ANDAMAN & NICOBAR ',
#        'RAJSHTHAN', 'NL', 'MIZORAM', 'ORISSA', 'LAKSHADWEEP', 'PB', 'APO',
#        'AR', 'PONDICHERRY', 'RAJSTHAN'], dtype=object)

# %%
dataset['ship-state']=dataset['ship-state'].str.replace('ORISSA', 'ODISHA')
dataset['ship-state'].unique()
# Out:
# array(['MAHARASHTRA', 'KARNATAKA', 'PUDUCHERRY', 'TAMIL NADU',
#        'UTTAR PRADESH', 'CHANDIGARH', 'TELANGANA', 'ANDHRA PRADESH',
#        'RAJASTHAN', 'NEW DELHI', 'HARYANA', 'ASSAM', 'JHARKHAND',
#        'CHHATTISGARH', 'ODISHA', 'KERALA', 'MADHYA PRADESH',
#        'WEST BENGAL', 'NAGALAND', 'GUJARAT', 'UTTARAKHAND', 'BIHAR',
#        'JAMMU & KASHMIR', 'PUNJAB', 'HIMACHAL PRADESH',
#        'ARUNACHAL PRADESH', 'MANIPUR', 'GOA', 'MEGHALAYA', 'TRIPURA',
#        'LADAKH', 'DADRA AND NAGAR', 'SIKKIM', 'ANDAMAN & NICOBAR ',
#        'RAJSHTHAN', 'NL', 'MIZORAM', 'LAKSHADWEEP', 'PB', 'APO', 'AR',
#        'PONDICHERRY', 'RAJSTHAN'], dtype=object)

# %%
dataset['ship-state']=dataset['ship-state'].str.replace('RAJSHTHAN', 'RAJASTHAN')
dataset['ship-state'].unique()
# Out:
# array(['MAHARASHTRA', 'KARNATAKA', 'PUDUCHERRY', 'TAMIL NADU',
#        'UTTAR PRADESH', 'CHANDIGARH', 'TELANGANA', 'ANDHRA PRADESH',
#        'RAJASTHAN', 'NEW DELHI', 'HARYANA', 'ASSAM', 'JHARKHAND',
#        'CHHATTISGARH', 'ODISHA', 'KERALA', 'MADHYA PRADESH',
#        'WEST BENGAL', 'NAGALAND', 'GUJARAT', 'UTTARAKHAND', 'BIHAR',
#        'JAMMU & KASHMIR', 'PUNJAB', 'HIMACHAL PRADESH',
#        'ARUNACHAL PRADESH', 'MANIPUR', 'GOA', 'MEGHALAYA', 'TRIPURA',
#        'LADAKH', 'DADRA AND NAGAR', 'SIKKIM', 'ANDAMAN & NICOBAR ', 'NL',
#        'MIZORAM', 'LAKSHADWEEP', 'PB', 'APO', 'AR', 'PONDICHERRY',
#        'RAJSTHAN'], dtype=object)

# %%
dataset['ship-state']=dataset['ship-state'].str.replace('RAJSTHAN', 'RAJASTHAN')
dataset['ship-state'].unique()
# Out:
# array(['MAHARASHTRA', 'KARNATAKA', 'PUDUCHERRY', 'TAMIL NADU',
#        'UTTAR PRADESH', 'CHANDIGARH', 'TELANGANA', 'ANDHRA PRADESH',
#        'RAJASTHAN', 'NEW DELHI', 'HARYANA', 'ASSAM', 'JHARKHAND',
#        'CHHATTISGARH', 'ODISHA', 'KERALA', 'MADHYA PRADESH',
#        'WEST BENGAL', 'NAGALAND', 'GUJARAT', 'UTTARAKHAND', 'BIHAR',
#        'JAMMU & KASHMIR', 'PUNJAB', 'HIMACHAL PRADESH',
#        'ARUNACHAL PRADESH', 'MANIPUR', 'GOA', 'MEGHALAYA', 'TRIPURA',
#        'LADAKH', 'DADRA AND NAGAR', 'SIKKIM', 'ANDAMAN & NICOBAR ', 'NL',
#        'MIZORAM', 'LAKSHADWEEP', 'PB', 'APO', 'AR', 'PONDICHERRY'],
#       dtype=object)

# %%
dataset['ship-state']=dataset['ship-state'].replace({'PB': 'PUNJAB', 'NL': 'NAGALAND'})
dataset['ship-state'].unique()
# Out:
# array(['MAHARASHTRA', 'KARNATAKA', 'PUDUCHERRY', 'TAMIL NADU',
#        'UTTAR PRADESH', 'CHANDIGARH', 'TELANGANA', 'ANDHRA PRADESH',
#        'RAJASTHAN', 'NEW DELHI', 'HARYANA', 'ASSAM', 'JHARKHAND',
#        'CHHATTISGARH', 'ODISHA', 'KERALA', 'MADHYA PRADESH',
#        'WEST BENGAL', 'NAGALAND', 'GUJARAT', 'UTTARAKHAND', 'BIHAR',
#        'JAMMU & KASHMIR', 'PUNJAB', 'HIMACHAL PRADESH',
#        'ARUNACHAL PRADESH', 'MANIPUR', 'GOA', 'MEGHALAYA', 'TRIPURA',
#        'LADAKH', 'DADRA AND NAGAR', 'SIKKIM', 'ANDAMAN & NICOBAR ',
#        'MIZORAM', 'LAKSHADWEEP', 'APO', 'AR', 'PONDICHERRY'], dtype=object)

# %%
for index, row in dataset.iterrows():
    if '407-1375529-7104311' in row['Order ID']:
        dataset['ship-state'][index] = 'ARUNACHAL PRADESH'
dataset['ship-state'].unique()
# Out:
# C:\Users\sanja\AppData\Local\Temp\ipykernel_15564\1919728636.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset['ship-state'][index] = 'ARUNACHAL PRADESH'
# array(['MAHARASHTRA', 'KARNATAKA', 'PUDUCHERRY', 'TAMIL NADU',
#        'UTTAR PRADESH', 'CHANDIGARH', 'TELANGANA', 'ANDHRA PRADESH',
#        'RAJASTHAN', 'NEW DELHI', 'HARYANA', 'ASSAM', 'JHARKHAND',
#        'CHHATTISGARH', 'ODISHA', 'KERALA', 'MADHYA PRADESH',
#        'WEST BENGAL', 'NAGALAND', 'GUJARAT', 'UTTARAKHAND', 'BIHAR',
#        'JAMMU & KASHMIR', 'PUNJAB', 'HIMACHAL PRADESH',
#        'ARUNACHAL PRADESH', 'MANIPUR', 'GOA', 'MEGHALAYA', 'TRIPURA',
#        'LADAKH', 'DADRA AND NAGAR', 'SIKKIM', 'ANDAMAN & NICOBAR ',
#        'MIZORAM', 'LAKSHADWEEP', 'APO', 'PONDICHERRY'], dtype=object)

# %%
dataset.to_csv('Amazon_Report.csv')

# %%
dataset.isna().sum()
# Out:
# Order ID              0
# Date                  0
# Status                0
# Fulfilment            0
# Sales Channel         0
# ship-service-level    0
# Style                 0
# SKU                   0
# Category              0
# Size                  0
# ASIN                  0
# Courier Status        0
# Qty                   0
# currency              0
# Amount                0
# ship-city             0
# ship-state            0
# ship-postal-code      0
# ship-country          0
# promotion-ids         0
# B2B                   0
# fulfilled-by          0
# dtype: int64
